# %%
right_sensor=False
left_sensor=True
front_sensor=True
correct_path="rrrffffffrr"
robot_path=""
print("front: ",front_sensor,"right: ",right_sensor,"left: ",left_sensor)
# n=1
# while(True):
    
#     direction = input("Enter the direction: ")
#     if((direction=="right") or direction=="Right"):
#         robot_path=robot_path[0:len(robot_path)] + "r"
#         if((n<=1) and (n>=2):
#             right_sensor=False
#             left_sensor=False
#             front_sensor=True
#             n=n+1
#         print("front: ",front_sensor,"right: ",right_sensor,"left: ",left_sensor)
        
        
        
#     elif ((direction=="forward") or (direction=="Forward")):
#         robot_path=robot_path[0:len(robot_path)]+"f"
        
#     elif ((direction=="left") or (direction=="Left")):
#         robot_path=robot_path[0:len(robot_path)]+"l"
        
#     print(robot_path)
#     if (robot_path == correct_path):
#         print("you solved the maze.")
#         break



#print(correct_path[0:len(correct_path)]+"d")

# a=""
# b="abc"
# if a==b:
#     print("true")
# else: print("false")


n=1
while(True):
        print(robot_path)
        direction = input("Enter the direction: ")
        if((direction=="right") or (direction=="Right")):
            
            n=n+1
            if (robot_path!="") and (robot_path!="r") and (robot_path!="rr") and (robot_path!="rr") and (robot_path!="rrrffffff") and (robot_path!="rrrffffffr")and (robot_path!="rrrfff") and ((robot_path!="rrrf") or (robot_path!="rrrff")):
                print("there is a wall at right side.")
            else:
                robot_path=robot_path[0:len(robot_path)] + "r"
                
            
        elif ((direction=="forward") or (direction=="Forward")):
            
            if (robot_path=="") or (robot_path=="r") or (robot_path=="rr") or (robot_path=="rrrffffff") or (robot_path=="rrrffffffr"):
                print("wall infront of you! you cannot go there")
            else: 
                robot_path=robot_path[0:len(robot_path)]+"f" 
            
        elif ((direction=="left") or (direction=="Left")):
                
            if (robot_path!="r") and (robot_path!="rr") and (robot_path!="rrr") and (robot_path!="rrrffffffr"):
                print("there is a wall at you left. you cannot move left.")
            else:
                robot_path=robot_path[0:len(robot_path)]+"l"
                
        elif((direction=="back") or (direction=="Back")):
            
            if (robot_path!="rrrf") and (robot_path!="rrrfffrr") and (robot_path!="rrrfffrrb") and (robot_path!="rrrfffrrbb") and (robot_path!="rrrfff") and (robot_path!="rrrff") and (robot_path!="rrrffff") and (robot_path!="rrrfffff") and ((robot_path!="rrrffffff") or (robot_path=="rrrffffffr"))  :
                print("there is a wall at your back. you cannot move back")
            else:
                robot_path=robot_path[0:len(robot_path)]+"b"
                    
        if (n!=1):
            if (robot_path[-1]=="l") and (robot_path[-2]=="r"):
                robot_path=robot_path[0:-2]
                
            elif (robot_path[-1]=="b") and (robot_path[-2]=="f"):
                robot_path=robot_path[0:-2]
            elif (robot_path[-1]=="f") and (robot_path[-2]=="b"):
                robot_path=robot_path[0:-2]
        
        
        if (robot_path == correct_path):
            print("you solved the maze.")
            break

        #issue: after rrrfff robot should accept right command but it is saying there is no way...
# Out:
# front:  True right:  False left:  True
#
# Enter the direction: left
# there is a wall at you left. you cannot move left.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 45>()
#      45 while(True):
#      46         print(robot_path)
# ---> 47         direction = input("Enter the direction: ")
#      48         if((direction=="right") or (direction=="Right")):
#      50             n=n+1
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
